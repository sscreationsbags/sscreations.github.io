# %%
import pandas as pd
import os

# %%
df = pd.DataFrame()

# %%
images = []
for image in os.listdir("../pictures/bags/"):
    if ".jpg" in image:
        images.append(image)

# %%
df["image_path"] = images

# %%
df
# Out:
#                    image_path
# 0            butterflybag.jpg
# 1            examplegreen.jpg
# 2           sundariposter.jpg
# 3             blackboxbag.jpg
# 4              omjaisaree.jpg
# 5   blackandhwhitechecked.jpg
# 6   omprakashkailashchand.jpg
# 7                 aristea.jpg
# 8            goldenboxbag.jpg
# 9   goldenflowerturquoise.jpg
# 10            examplepink.jpg
# 11              flowerbag.jpg
# 12                shrinay.jpg
# 13        indiandesignred.jpg
# 14                rosebig.jpg
# 15           reemayurlady.jpg
# 16              redboxbag.jpg
# 17            shivshankar.jpg
# 18        solidgreyboxbag.jpg
# 19       indiandesignblue.jpg
# 20           metallicgold.jpg
# 21       pansheelhandloom.jpg
# 22                kasturi.jpg
# 23             twosisters.jpg
# 24                 rivoli.jpg
# 25        jalidesignblack.jpg
# 26        jalidesignwhite.jpg
# 27         supertexstyles.jpg
# 28             vashugreen.jpg
# 29           purpleboxbag.jpg
# ...

# %%
df.to_excel("sscreations_data.xlsx", index=False)
